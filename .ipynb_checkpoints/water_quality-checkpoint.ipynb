# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('water_potability.csv')

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.tail()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
# ph                 2785 non-null float64
# Hardness           3276 non-null float64
# Solids             3276 non-null float64
# Chloramines        3276 non-null float64
# Sulfate            2495 non-null float64
# Conductivity       3276 non-null float64
# Organic_carbon     3276 non-null float64
# Trihalomethanes    3114 non-null float64
# Turbidity          3276 non-null float64
# Potability         3276 non-null int64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB

# %%
df['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df['ph'].fillna(df['ph'].mean(), inplace=True)
df['Sulfate'].fillna(df['Sulfate'].mean(), inplace=True)
df['Trihalomethanes'].fillna(df['Trihalomethanes'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df.shape
# Out:
# (3276, 10)

# %%
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df_out.shape
# Out:
# (2666, 10)

# %%
sns.pairplot(df, kind='scatter')

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data=df.corr(),cmap='plasma', annot=True)
# Out:
# <AxesSubplot:>

# %%
X = df.drop(columns='Potability', axis=1)
y = df['Potability']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)

# %%
X_train
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 1580   6.129070  198.021095  22207.482865     7.387451  333.775777
# 530    6.641501  198.884409  27867.486757     7.327729  318.408397
# 2196   8.616824  228.762945  19126.298537     7.017578  327.894821
# 49     8.757257  200.191400  21536.224687     4.915101  317.882900
# 858    6.495435  252.010903  32775.632585     8.479302  333.775777
# 1072   7.080795  172.731433  28894.476970     4.250917  244.285145
# 719    7.080795  160.325972  37795.763318     9.152225  390.276608
# 2401   4.083595  201.938643  20555.965489     1.920271  341.597153
# 3041   6.711815  232.206428  23936.275332     6.619088  333.775777
# 2460   8.848103  248.567740  19793.971867     9.681154  323.351749
# 1567   7.080795  187.043283  24634.552443     9.081880  333.775777
# 3011   6.901111  154.474092  21103.303188     7.928700  376.001071
# 2328   6.071839  217.826531  17162.753927     3.521125  319.037346
# 1557   7.580049  225.088555  31749.924396     5.884795  333.775777
# 2441   6.304769  213.656178  30168.606596     5.210780  333.775777
# 1554   8.942046  215.673786  56488.672413     3.231438  129.000000
# 2254   8.303264  232.414673  16548.356730     6.343523  301.087247
# 1498   7.080795  184.786038  18113.017302     8.319080  381.513212
# 1196   7.080795  212.909132  14101.869292     9.112485  388.787785
# 2802   5.230454  152.094169  24790.724599     6.308730  388.998079
# 2342   7.835907  206.665788  17643.407147     8.137484  333.775777
# 1376   5.669819  203.452715  27244.634470     6.604950  333.775777
# 2870   7.080795  176.386651  26003.163265     7.809251  358.429774
# 2993   3.102076  198.488651  45148.808118     7.821650  324.644080
# 297    7.080795  191.285218  21948.325362     5.626787  355.488766
# 2766   7.493844  197.331291  26678.392879     7.198435  269.892347
# 1441  10.301571  199.609364  11278.829678     7.464893  433.448168
# 958    7.574261  227.984665   8672.527773     7.335362  333.775777
# 2459   5.842359  217.324800  29644.813606     4.179108  328.503921
# 1457   5.488135  192.507984  21715.774409     5.454063  333.775777
# ...         ...         ...           ...          ...         ...
# 747    7.702183  192.137531  18126.030963     9.154581  364.191227
# 2300   2.974429  147.148675  17326.202253     2.498597  393.168745
# 21     6.660212  168.283747  30944.363591     5.858769  310.930858
# 459    8.639541  168.613967   7013.211787     8.451601  355.213897
# 1184   6.632032  201.669933  24161.254979     7.964525  369.621585
# 2324   3.975753  135.891978  17430.841944     6.305788  373.486425
# 955    9.066628  203.384123  22710.458374     5.962837  321.585936
# 1215   7.968526  156.451149  27008.011874     4.716577  333.775777
# 2433   7.080795  240.036279  23103.653539     8.643089  339.158877
# 2853   5.272156  181.732877  19015.468275     9.013016  446.724016
# 1515   7.330197  159.803720  14884.339958     9.194575  411.100692
# 2391   7.080795  152.537418  19731.749181    10.886742  373.988714
# 769    5.729303  162.857585  34573.678786     5.654856  415.287072
# 1685   6.920389  252.352799  11086.259858     9.993376  285.744758
# 130    6.643936  151.889600  10909.194592     3.749625  240.936722
# 2919   6.898932  209.636422  15422.220893     6.884918  293.562020
# 3171   7.273368  175.015083  14206.357323     7.839067  337.644573
# 2135   7.080795  184.020029  13361.226016     9.258656  335.089993
# 1482   7.015333  222.113004  16351.226287     7.838884  353.189806
# 330    6.737004  220.100102  24694.744205     8.373660  333.775777
# 1238   6.582500  200.733107  23720.481730     8.565832  353.008115
# 466    7.539882  185.825975  21575.245221     7.442999  333.079630
# 2169   8.179890  258.901939  17291.618256     5.184410  333.775777
# 1638   7.080795  186.365549   7557.021271     9.454207  406.038068
# 3092   7.260320  194.247742   8127.071254     6.674032  394.555835
# 1095   4.187491  208.374188  21809.709834     5.846112  327.474203
# 1130   7.793915  164.958947  25506.912237     7.868036  358.259200
# 1294   6.630364  186.761088  30939.023214     7.703481  333.775777
# 860    8.783168  218.032840  16183.586649     7.390474  334.053885
# 3174   6.698154  198.286268  34675.862845     6.263602  360.232834
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 1580    464.851322       14.028602        61.446945   3.837639
# 530     573.723762       13.191720        81.551114   4.694311
# 2196    383.527023       14.759257        41.275927   4.584566
# 49      404.717799       13.768323        47.930872   3.626135
# 858     330.045052        9.854011        80.561077   3.390471
# 1072    559.629340       21.340849        51.274712   2.959750
# 719     441.986106       16.450990        21.355275   4.441980
# 2401    435.511529       12.226676        69.289779   2.974871
# 3041    463.510297       13.911879        78.190897   3.413647
# 2460    411.147433       18.137805        68.753074   3.074799
# 1567    443.843399       11.053925        74.108180   3.498717
# 3011    450.252974       14.643306        71.321372   3.616498
# 2328    612.094926       16.542239        64.826308   2.691610
# 1557    503.908733       18.502406        78.354341   3.959637
# 2441    339.116587       14.947676        43.576389   5.109935
# 1554    541.915468        9.313771        70.828374   4.354288
# 2254    395.339102       13.789985        78.620715   3.892667
# 1498    530.248387       19.385941        70.957565   3.077035
# 1196    337.191083        8.602425        74.581711   3.624635
# 2802    307.918075       12.594197        51.625213   3.695615
# 2342    474.989773       16.167186        68.082265   3.183864
# 1376    361.238480       11.095060        68.923128   5.600459
# 2870    336.142005       14.447961        90.224844   4.410674
# 2993    427.216764       15.530123        54.574254   4.248075
# 297     509.406822       16.691471        84.107738   4.109590
# 2766    375.503062       13.134917        69.590806   3.819947
# 1441    461.979286       17.099096        63.190835   3.857852
# 958     433.679543       11.238914        54.865889   3.686759
# 2459    310.771178       14.335395        62.654956   3.865296
# 1457    553.287241       13.081524        87.279537   3.652991
# ...            ...             ...              ...        ...
# 747     646.732599       14.376337        90.527536   4.382159
# 2300    375.411470       12.798187        76.413069   2.779902
# 21      523.671298       17.884235        77.042318   3.749701
# 459     419.788898       17.929395        33.641539   4.192932
# 1184    346.860405       17.033602        61.205470   3.386294
# 2324    344.398912       15.624310        68.370968   3.666824
# 955     496.161452       18.367621        76.416510   4.055421
# 1215    455.840428        8.360283        52.501187   3.173879
# 2433    487.434555       15.193704        88.785469   3.980920
# 2853    390.012003       11.103467        63.826010   4.063826
# 1515    404.195912       17.375739        51.153972   2.884715
# 2391    463.747681       15.534904        61.151290   5.294159
# 769     297.631365       13.990842        76.744677   3.556395
# 1685    368.629147       17.120803        43.667082   3.277601
# 130     437.909005       15.264742        64.203964   3.812953
# 2919    396.811214       15.671717        66.597336   3.688456
# 3171    322.490689       18.107842        58.181707   4.196421
# 2135    467.444154       19.581926        80.084233   4.411058
# 1482    420.136873        8.840514        66.543935   5.251223
# 330     384.308673        6.748092         8.175876   4.063170
# 1238    458.362733       13.001881        79.529338   4.152014
# 466     444.116633       15.830565        49.067977   4.531594
# 2169    434.504238       12.813028        51.095711   4.295738
# 1638    288.368713       12.861417        72.187015   4.116263
# 3092    312.349017       16.005022        65.023960   4.282315
# 1095    264.508083       11.235144        46.682597   4.592959
# 1130    398.460312       15.297496        66.396293   4.220028
# 1294    330.876083       13.815757        86.753117   3.490588
# 860     389.021616       16.354520        47.100982   4.274137
# 3174    430.935009       12.176678        66.396293   3.758180
#
# [2129 rows x 9 columns]

# %%
sns.countplot(x=y_train)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='count'>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
scaled_data = scaler.transform(X_train)

# %%
scaled_data
# Out:
# array([[ 0.35329982,  0.47411639,  0.26547456, ...,  1.18380656,
#         -0.9063429 ,  0.65215374],
#        [ 1.32989796,  1.57472124,  0.17352147, ...,  1.37752046,
#          0.23795534, -0.11013481],
#        [ 0.56875154,  0.30586745,  1.60555544, ...,  1.57867343,
#          0.96166628,  0.83065453],
#        ...,
#        [-0.85693997,  1.03946559, -1.09697454, ..., -2.22692818,
#         -1.70185717, -0.47651859],
#        [ 0.00651023, -0.09739247,  2.09734622, ..., -0.16540372,
#         -0.39816913, -0.78778001],
#        [ 0.68383821, -0.34611154,  1.34633426, ...,  1.7413866 ,
#         -1.31528919,  0.64388004]])

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score

# %%
pipe1 = Pipeline([('scaler', StandardScaler()), ('lg_model', LogisticRegression())])
# pipe1.fit(X_train, y_train)
# pipe1.score(X_test, y_test)
lg_score = cross_val_score(pipe1, X, y, cv=5)
lg_score.mean()
# Out:
# 0.6267814856195234

# %%
pipe2 = Pipeline([('scaler', StandardScaler()), ('rf', RandomForestClassifier())])
# pipe2.fit(X_train, y_train)
# pipe2.score(X_test, y_test)
rf_score = cross_val_score(pipe2, X, y, cv=5)
rf_score.mean()
# Out:
# 1.0

# %%
pipe3 = Pipeline([('scaler', StandardScaler()), ('gnb', GaussianNB())])
# pipe3.fit(X_train, y_train)
# pipe3.score(X_test, y_test)
gnb_score = cross_val_score(pipe3, X, y, cv=5)
gnb_score.mean()
# Out:
# 0.6061590460329842

# %%
pipe4 = Pipeline([('scaler', StandardScaler()), ('neigh', KNeighborsClassifier(n_neighbors=8))])
# pipe4.fit(X_train, y_train)
# pipe4.score(X_test, y_test)
knn_score = cross_val_score(pipe4, X, y, cv=5)
knn_score.mean()
# Out:
# 0.6091510845964121

# %%
pipe5 = Pipeline([('scaler', StandardScaler()), ('svc', SVC())])
# pipe4.fit(X_train, y_train)
# pipe4.score(X_test, y_test)
svc_score = cross_val_score(pipe5, X, y, cv=5)
svc_score.mean()
# Out:
# 0.6339137522749472

# %%
svc_score
# Out:
# array([0.61985019, 0.63789869, 0.66228893, 0.59099437, 0.65853659])

# %%
rf_score
# Out:
# array([0.60674157, 0.63414634, 0.62664165, 0.58536585, 0.63977486])

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001]}
grid = GridSearchCV(SVC(), param_grid)

# %%
grid.fit(X, y)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001]})

# %%
grid.best_score_
# Out:
# 0.6267814856195234

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1}

# %%
param_grid = {'max_depth': [3, 5, 10],
               'min_samples_split': [2, 5, 10]}
grid2 = GridSearchCV(RandomForestClassifier(), param_grid, refit = True, cv=5)

# %%
grid2.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [3, 5, 10],
#                          'min_samples_split': [2, 5, 10]})

# %%
grid2.best_score_
# Out:
# 0.6294137487615152

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(df['Sulfate'])
 
# show plot
plt.show()

# %%
RandomForest_Pipeline     = Pipeline(steps = [('scale',StandardScaler()),('RF',RandomForestClassifier(random_state=42))])
AdaBoost_Pipeline         = Pipeline(steps = [('scale',StandardScaler()),('AB',AdaBoostClassifier(random_state=42))])
SVC_Pipeline              = Pipeline(steps = [('scale',StandardScaler()),('SVM',SVC(random_state=42))])

RandomForest_CV_f1     = cross_val_score(RandomForest_Pipeline,X,y,cv=10,scoring='accuracy')
AdaBoost_CV_f1         = cross_val_score(AdaBoost_Pipeline,X,y,cv=10,scoring='accuracy')
SVC_CV_f1              = cross_val_score(SVC_Pipeline,X,y,cv=10,scoring='accuracy')

# %%
RandomForest_CV_f1
# Out:
# array([0.66158537, 0.61890244, 0.67378049, 0.66158537, 0.6402439 ,
#        0.57012195, 0.59327217, 0.63914373, 0.67584098, 0.6911315 ])

# %%
AdaBoost_CV_f1
# Out:
# array([0.63109756, 0.61890244, 0.66158537, 0.62195122, 0.65853659,
#        0.50304878, 0.52599388, 0.59021407, 0.6146789 , 0.58409786])

# %%
SVC_CV_f1
# Out:
# array([0.6554878 , 0.61585366, 0.68292683, 0.67987805, 0.67073171,
#        0.59146341, 0.62385321, 0.63914373, 0.65137615, 0.6911315 ])

# %%
#from tune_sklearn  import TuneGridSearchCV

RFBE = RandomForestClassifier(random_state=42)

AdaBoost_Pipeline         = Pipeline(steps = [('scale',StandardScaler()),('AB',AdaBoostClassifier(random_state = 42,
                                                                                                  base_estimator = RFBE))])

AdaBoost_Pipeline.fit(X_train,y_train)

parameters = {'AB__base_estimator__max_depth':[2,3,5],
               'AB__base_estimator__min_samples_leaf':[2,5,10],
               'AB__base_estimator__criterion':['entropy','gini'],
               'AB__base_estimator__bootstrap':[True,False],
               'AB__n_estimators':[5,10,25],
               'AB__learning_rate':[0.01,0.1]}

#ADA_RF_GS  = TuneGridSearchCV(AdaBoost_Pipeline,parameters,cv=3,verbose=1)
ADA_RF_GS  = GridSearchCV(AdaBoost_Pipeline,parameters,cv=3,verbose=10)
ADA_RF_GS.fit(X,y)
print("Best parameter (CV score=%0.3f):" % ADA_RF_GS.best_score_)
print(ADA_RF_GS.best_params_)
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [CV 1/3; 1/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 1/3; 1/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.8s
# [CV 2/3; 1/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 1/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.8s
# [CV 3/3; 1/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 1/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.7s
# [CV 1/3; 2/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 2/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.7s
# [CV 2/3; 2/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 2/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.9s
# [CV 3/3; 2/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 2/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.9s
# [CV 1/3; 3/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 3/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25; total time=   9.1s
# [CV 2/3; 3/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 3/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25; total time=   8.6s
# [CV 3/3; 3/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 3/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25; total time=   9.0s
# [CV 1/3; 4/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 4/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.9s
# [CV 2/3; 4/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 4/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.7s
# [CV 3/3; 4/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 4/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.6s
# [CV 1/3; 5/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 5/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.4s
# [CV 2/3; 5/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 5/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.7s
# [CV 3/3; 5/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 5/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.3s
# [CV 1/3; 6/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 6/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25; total time=   8.3s
# [CV 2/3; 6/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 6/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25; total time=   9.8s
# [CV 3/3; 6/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 3/3; 6/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.5s
# [CV 1/3; 7/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 1/3; 7/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.9s
# [CV 2/3; 7/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 7/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.7s
# [CV 3/3; 7/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 7/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.6s
# [CV 1/3; 8/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 8/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.6s
# [CV 2/3; 8/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 8/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.3s
# [CV 3/3; 8/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 8/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.8s
# [CV 1/3; 9/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 9/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=   8.3s
# [CV 2/3; 9/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 9/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=   8.9s
# [CV 3/3; 9/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 9/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=   8.4s
# [CV 1/3; 10/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 10/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.6s
# [CV 2/3; 10/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 10/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.6s
# [CV 3/3; 10/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 10/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.1s
# [CV 1/3; 11/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 11/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.3s
# [CV 2/3; 11/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 11/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.6s
# [CV 3/3; 11/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 11/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.7s
# [CV 1/3; 12/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 12/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=   8.9s
# [CV 2/3; 12/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 12/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=   8.4s
# [CV 3/3; 12/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 3/3; 12/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=   8.9s
# [CV 1/3; 13/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 1/3; 13/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.6s
# [CV 2/3; 13/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 13/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.6s
# [CV 3/3; 13/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 13/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.6s
# [CV 1/3; 14/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 14/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.2s
# [CV 2/3; 14/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 14/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.7s
# [CV 3/3; 14/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 14/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.2s
# [CV 1/3; 15/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 15/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=   8.3s
# [CV 2/3; 15/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 15/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=   9.0s
# [CV 3/3; 15/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 15/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=   9.4s
# [CV 1/3; 16/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 16/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.6s
# [CV 2/3; 16/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 16/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.6s
# [CV 3/3; 16/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 16/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.6s
# [CV 1/3; 17/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 17/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.3s
# [CV 2/3; 17/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 17/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.3s
# [CV 3/3; 17/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 17/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   3.7s
# [CV 1/3; 18/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 18/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=   8.3s
# [CV 2/3; 18/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 18/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=   8.9s
# [CV 3/3; 18/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 3/3; 18/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=2, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=   8.3s
# [CV 1/3; 19/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 1/3; 19/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.9s
# [CV 2/3; 19/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 19/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.9s
# [CV 3/3; 19/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 19/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.5s
# [CV 1/3; 20/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 20/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.5s
# [CV 2/3; 20/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 20/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.4s
# [CV 3/3; 20/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 20/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=10; total time=   5.9s
# [CV 1/3; 21/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 21/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.4s
# [CV 2/3; 21/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 21/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.7s
# [CV 3/3; 21/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 21/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.2s
# [CV 1/3; 22/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 22/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.2s
# [CV 2/3; 22/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 22/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.0s
# [CV 3/3; 22/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 22/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.0s
# [CV 1/3; 23/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 23/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.0s
# [CV 2/3; 23/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 23/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.1s
# [CV 3/3; 23/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 23/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.5s
# [CV 1/3; 24/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 24/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.5s
# [CV 2/3; 24/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 24/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.8s
# [CV 3/3; 24/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 3/3; 24/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=2, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.5s
# [CV 1/3; 25/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 1/3; 25/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.9s
# [CV 2/3; 25/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 25/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.9s
# [CV 3/3; 25/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 25/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.9s
# [CV 1/3; 26/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 26/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   3.9s
# [CV 2/3; 26/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 26/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.5s
# [CV 3/3; 26/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 26/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.0s
# [CV 1/3; 27/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 27/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.5s
# [CV 2/3; 27/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 27/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.2s
# [CV 3/3; 27/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 27/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=  11.1s
# [CV 1/3; 28/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 28/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.1s
# [CV 2/3; 28/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 28/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   1.9s
# [CV 3/3; 28/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 28/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.0s
# [CV 1/3; 29/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 29/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.9s
# [CV 2/3; 29/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 29/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.0s
# [CV 3/3; 29/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 29/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.0s
# [CV 1/3; 30/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 30/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.8s
# [CV 2/3; 30/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 30/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.1s
# [CV 3/3; 30/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 3/3; 30/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.5s
# [CV 1/3; 31/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 1/3; 31/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.0s
# [CV 2/3; 31/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 31/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   1.9s
# [CV 3/3; 31/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 31/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.3s
# [CV 1/3; 32/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 32/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.8s
# [CV 2/3; 32/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 32/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.1s
# [CV 3/3; 32/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 32/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.0s
# [CV 1/3; 33/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 33/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.8s
# [CV 2/3; 33/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 33/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.6s
# [CV 3/3; 33/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 33/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=  10.1s
# [CV 1/3; 34/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 34/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.0s
# [CV 2/3; 34/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 34/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.7s
# [CV 3/3; 34/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 34/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.2s
# [CV 1/3; 35/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 35/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.0s
# [CV 2/3; 35/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 35/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.0s
# [CV 3/3; 35/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 35/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.6s
# [CV 1/3; 36/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 36/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=  11.6s
# [CV 2/3; 36/216] START AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 36/216] END AB__base_estimator__bootstrap=True, AB__base_estimator__criterion=entropy, AB__base_estimator__max_depth=3, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=  10.5s
# ...
# [CV 2/3; 205/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 205/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.3s
# [CV 3/3; 205/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 205/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.3s
# [CV 1/3; 206/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 206/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   5.2s
# [CV 2/3; 206/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 206/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.7s
# [CV 3/3; 206/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 206/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.7s
# [CV 1/3; 207/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 207/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=  13.1s
# [CV 2/3; 207/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 207/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=  12.4s
# [CV 3/3; 207/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 207/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.01, AB__n_estimators=25; total time=  12.4s
# [CV 1/3; 208/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 208/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.4s
# [CV 2/3; 208/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 208/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.4s
# [CV 3/3; 208/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 208/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.3s
# [CV 1/3; 209/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 209/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.8s
# [CV 2/3; 209/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 209/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   5.2s
# [CV 3/3; 209/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 209/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=10; total time=   7.3s
# [CV 1/3; 210/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 210/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=  16.4s
# [CV 2/3; 210/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 210/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=  12.3s
# [CV 3/3; 210/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 3/3; 210/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=5, AB__learning_rate=0.1, AB__n_estimators=25; total time=  13.6s
# [CV 1/3; 211/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 1/3; 211/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.3s
# [CV 2/3; 211/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 2/3; 211/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.3s
# [CV 3/3; 211/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5
# [CV 3/3; 211/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=5; total time=   2.3s
# [CV 1/3; 212/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 1/3; 212/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   5.1s
# [CV 2/3; 212/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 2/3; 212/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.8s
# [CV 3/3; 212/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10
# [CV 3/3; 212/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=10; total time=   4.7s
# [CV 1/3; 213/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 1/3; 213/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=  12.9s
# [CV 2/3; 213/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 2/3; 213/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=  12.4s
# [CV 3/3; 213/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25
# [CV 3/3; 213/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.01, AB__n_estimators=25; total time=  12.0s
# [CV 1/3; 214/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 1/3; 214/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.6s
# [CV 2/3; 214/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 2/3; 214/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.3s
# [CV 3/3; 214/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5
# [CV 3/3; 214/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=5; total time=   2.3s
# [CV 1/3; 215/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 1/3; 215/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.7s
# [CV 2/3; 215/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 2/3; 215/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   5.3s
# [CV 3/3; 215/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10
# [CV 3/3; 215/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=10; total time=   4.7s
# [CV 1/3; 216/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 1/3; 216/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=  12.8s
# [CV 2/3; 216/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 2/3; 216/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=  12.7s
# [CV 3/3; 216/216] START AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25
# [CV 3/3; 216/216] END AB__base_estimator__bootstrap=False, AB__base_estimator__criterion=gini, AB__base_estimator__max_depth=5, AB__base_estimator__min_samples_leaf=10, AB__learning_rate=0.1, AB__n_estimators=25; total time=  12.0s
# Best parameter (CV score=0.634):
# {'AB__base_estimator__bootstrap': True, 'AB__base_estimator__criterion': 'gini', 'AB__base_estimator__max_depth': 5, 'AB__base_estimator__min_samples_leaf': 10, 'AB__learning_rate': 0.01, 'AB__n_estimators': 10}

# %%
import numpy as np
RFBE = RandomForestClassifier(random_state=42,bootstrap=True,criterion='gini',max_depth=5,min_samples_leaf=10)
AdaBoost_Pipeline = Pipeline(steps = [('scale',StandardScaler()),('AB',AdaBoostClassifier(random_state = 42,
                                                                                                 base_estimator = RFBE,
                                                                                                 learning_rate=0.01,
                                                                                                 n_estimators=5))])

AdaBoost_Pipeline.fit(X_train,y_train)
f1 = AdaBoost_Pipeline.score(X_test,y_test)
print('F1 - Score of AdaBoost Model with Random Forest Base Estimators and Cross Validation Grid Search -[',np.round(f1,2),']')
# Out:
# F1 - Score of AdaBoost Model with Random Forest Base Estimators and Cross Validation Grid Search -[ 0.66 ]

# %%
AdaBoost_CV_f1  = cross_val_score(AdaBoost_Pipeline,X,y,cv=10,scoring='accuracy')
AdaBoost_CV_f1
# Out:
# array([0.61585366, 0.62195122, 0.65243902, 0.6402439 , 0.68902439,
#        0.58231707, 0.59633028, 0.6146789 , 0.63914373, 0.62996942])

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier(random_state=42)
scores = cross_val_score(hgb, X, y, cv=10)

scores
# Out:
# array([0.64329268, 0.60365854, 0.63414634, 0.62195122, 0.64939024,
#        0.55487805, 0.55963303, 0.62691131, 0.63608563, 0.65137615])
